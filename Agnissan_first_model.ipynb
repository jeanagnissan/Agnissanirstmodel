# %% [markdown]
# ## INPORTATION DES MODULES

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ##  CHARGER LE JEU DE DONNE

# %%
data = pd.read_excel('coeur.xlsx')
data
# Out:
#      AGE   SEXE  TDT  PAR  CHOLESTEROL  GAJ     ECG  FCMAX ANGINE  \
# 0     40  homme   AA  140          289    0  Normal    172    Non
# 1     49  femme  DNA  160          180    0  Normal    156    Non
# 2     37  homme   AA  130          283    0      ST     98    Non
# 3     48  femme  ASY  138          214    0  Normal    108    Oui
# 4     54  homme  DNA  150          195    0  Normal    122    Non
# ..   ...    ...  ...  ...          ...  ...     ...    ...    ...
# 913   45  homme   AT  110          264    0  Normal    132    Non
# 914   68  homme  ASY  144          193    1  Normal    141    Non
# 915   57  homme  ASY  130          131    0  Normal    115    Oui
# 916   57  femme   AA  130          236    0     LVH    174    Non
# 917   38  homme  DNA  138          175    0  Normal    173    Non
#
#      DEPRESSION       PENTE  CŒUR
# 0            0.0  Ascendant     0
# 1            1.0       Plat     1
# 2            0.0  Ascendant     0
# 3            1.5       Plat     1
# 4            0.0  Ascendant     0
# ..           ...        ...   ...
# 913          1.2       Plat     1
# 914          3.4       Plat     1
# 915          1.2       Plat     1
# 916          0.0       Plat     1
# 917          0.0  Ascendant     0
#
# [918 rows x 12 columns]

# %% [markdown]
# ## COPIE DE DATA DANS DF

# %%
df = data.copy()
df
# Out:
#      AGE   SEXE  TDT  PAR  CHOLESTEROL  GAJ     ECG  FCMAX ANGINE  \
# 0     40  homme   AA  140          289    0  Normal    172    Non
# 1     49  femme  DNA  160          180    0  Normal    156    Non
# 2     37  homme   AA  130          283    0      ST     98    Non
# 3     48  femme  ASY  138          214    0  Normal    108    Oui
# 4     54  homme  DNA  150          195    0  Normal    122    Non
# ..   ...    ...  ...  ...          ...  ...     ...    ...    ...
# 913   45  homme   AT  110          264    0  Normal    132    Non
# 914   68  homme  ASY  144          193    1  Normal    141    Non
# 915   57  homme  ASY  130          131    0  Normal    115    Oui
# 916   57  femme   AA  130          236    0     LVH    174    Non
# 917   38  homme  DNA  138          175    0  Normal    173    Non
#
#      DEPRESSION       PENTE  CŒUR
# 0            0.0  Ascendant     0
# 1            1.0       Plat     1
# 2            0.0  Ascendant     0
# 3            1.5       Plat     1
# 4            0.0  Ascendant     0
# ..           ...        ...   ...
# 913          1.2       Plat     1
# 914          3.4       Plat     1
# 915          1.2       Plat     1
# 916          0.0       Plat     1
# 917          0.0  Ascendant     0
#
# [918 rows x 12 columns]

# %% [markdown]
# ##  VERRIFIER LES DOUBLONS

# %%
doublon = df.duplicated()
doublon
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 913    False
# 914    False
# 915    False
# 916    False
# 917    False
# Length: 918, dtype: bool

# %%
dupli = df.drop_duplicates()
dupli
# Out:
#      AGE   SEXE  TDT  PAR  CHOLESTEROL  GAJ     ECG  FCMAX ANGINE  \
# 0     40  homme   AA  140          289    0  Normal    172    Non
# 1     49  femme  DNA  160          180    0  Normal    156    Non
# 2     37  homme   AA  130          283    0      ST     98    Non
# 3     48  femme  ASY  138          214    0  Normal    108    Oui
# 4     54  homme  DNA  150          195    0  Normal    122    Non
# ..   ...    ...  ...  ...          ...  ...     ...    ...    ...
# 913   45  homme   AT  110          264    0  Normal    132    Non
# 914   68  homme  ASY  144          193    1  Normal    141    Non
# 915   57  homme  ASY  130          131    0  Normal    115    Oui
# 916   57  femme   AA  130          236    0     LVH    174    Non
# 917   38  homme  DNA  138          175    0  Normal    173    Non
#
#      DEPRESSION       PENTE  CŒUR
# 0            0.0  Ascendant     0
# 1            1.0       Plat     1
# 2            0.0  Ascendant     0
# 3            1.5       Plat     1
# 4            0.0  Ascendant     0
# ..           ...        ...   ...
# 913          1.2       Plat     1
# 914          3.4       Plat     1
# 915          1.2       Plat     1
# 916          0.0       Plat     1
# 917          0.0  Ascendant     0
#
# [918 rows x 12 columns]

# %% [markdown]
# ## VERRIFIER LES DOUBLONS  SUR 1 LIGNE

# %%
doublon_ligne =  df.duplicated().value_counts()
doublon_ligne
# Out:
# False    918
# dtype: int64

# %% [markdown]
# ## SUPRIMER LES DOUBLONS  SUR 1 LIGNE

# %%
delet = df.drop_duplicates()
delet
# Out:
#      AGE   SEXE  TDT  PAR  CHOLESTEROL  GAJ     ECG  FCMAX ANGINE  \
# 0     40  homme   AA  140          289    0  Normal    172    Non
# 1     49  femme  DNA  160          180    0  Normal    156    Non
# 2     37  homme   AA  130          283    0      ST     98    Non
# 3     48  femme  ASY  138          214    0  Normal    108    Oui
# 4     54  homme  DNA  150          195    0  Normal    122    Non
# ..   ...    ...  ...  ...          ...  ...     ...    ...    ...
# 913   45  homme   AT  110          264    0  Normal    132    Non
# 914   68  homme  ASY  144          193    1  Normal    141    Non
# 915   57  homme  ASY  130          131    0  Normal    115    Oui
# 916   57  femme   AA  130          236    0     LVH    174    Non
# 917   38  homme  DNA  138          175    0  Normal    173    Non
#
#      DEPRESSION       PENTE  CŒUR
# 0            0.0  Ascendant     0
# 1            1.0       Plat     1
# 2            0.0  Ascendant     0
# 3            1.5       Plat     1
# 4            0.0  Ascendant     0
# ..           ...        ...   ...
# 913          1.2       Plat     1
# 914          3.4       Plat     1
# 915          1.2       Plat     1
# 916          0.0       Plat     1
# 917          0.0  Ascendant     0
#
# [918 rows x 12 columns]

# %% [markdown]
# ## VERRIFIER LES DONNES MANQUANTES

# %%
manqt = df.isna().value_counts()
manqt
# Out:
# AGE    SEXE   TDT    PAR    CHOLESTEROL  GAJ    ECG    FCMAX  ANGINE  DEPRESSION   PENTE  CŒUR
# False  False  False  False  False        False  False  False  False   False        False  False    918
# dtype: int64

# %% [markdown]
# ## SUPRIMER LES DONNES MANQUANTES

# %%
dele_dro = df.dropna()
dele_dro
# Out:
#      AGE   SEXE  TDT  PAR  CHOLESTEROL  GAJ     ECG  FCMAX ANGINE  \
# 0     40  homme   AA  140          289    0  Normal    172    Non
# 1     49  femme  DNA  160          180    0  Normal    156    Non
# 2     37  homme   AA  130          283    0      ST     98    Non
# 3     48  femme  ASY  138          214    0  Normal    108    Oui
# 4     54  homme  DNA  150          195    0  Normal    122    Non
# ..   ...    ...  ...  ...          ...  ...     ...    ...    ...
# 913   45  homme   AT  110          264    0  Normal    132    Non
# 914   68  homme  ASY  144          193    1  Normal    141    Non
# 915   57  homme  ASY  130          131    0  Normal    115    Oui
# 916   57  femme   AA  130          236    0     LVH    174    Non
# 917   38  homme  DNA  138          175    0  Normal    173    Non
#
#      DEPRESSION       PENTE  CŒUR
# 0            0.0  Ascendant     0
# 1            1.0       Plat     1
# 2            0.0  Ascendant     0
# 3            1.5       Plat     1
# 4            0.0  Ascendant     0
# ..           ...        ...   ...
# 913          1.2       Plat     1
# 914          3.4       Plat     1
# 915          1.2       Plat     1
# 916          0.0       Plat     1
# 917          0.0  Ascendant     0
#
# [918 rows x 12 columns]

# %% [markdown]
# ## SUPRIMER LES DONNES MANQUANTES VERRIFIER L'EXITANCE DE CONSTACNE

# %%
cont_manqt = df.nunique()
cont_manqt
# Out:
# AGE             50
# SEXE             2
# TDT              4
# PAR             67
# CHOLESTEROL    222
# GAJ              2
# ECG              3
# FCMAX          119
# ANGINE           2
# DEPRESSION      53
# PENTE            3
# CŒUR             2
# dtype: int64

# %%
#liste des variables quantitatives
quant_var = df.select_dtypes('int64', 'float32')

#je supprime la variable CŒUR de quant_var
quant_var = quant_var.drop(['CŒUR'], axis= 1)

#liste des variables qualitatives
qual_var = df.select_dtypes('object')

# %%
#normaliser les variables quantitatives 
def normaliser(datf):
    for col in quant_var:
        datf[col] = datf[col]/datf[col].max()
    return datf

normaliser(df)
# Out:
#           AGE   SEXE  TDT   PAR  CHOLESTEROL  GAJ     ECG     FCMAX ANGINE  \
# 0    0.519481  homme   AA  0.70     0.479270  0.0  Normal  0.851485    Non
# 1    0.636364  femme  DNA  0.80     0.298507  0.0  Normal  0.772277    Non
# 2    0.480519  homme   AA  0.65     0.469320  0.0      ST  0.485149    Non
# 3    0.623377  femme  ASY  0.69     0.354892  0.0  Normal  0.534653    Oui
# 4    0.701299  homme  DNA  0.75     0.323383  0.0  Normal  0.603960    Non
# ..        ...    ...  ...   ...          ...  ...     ...       ...    ...
# 913  0.584416  homme   AT  0.55     0.437811  0.0  Normal  0.653465    Non
# 914  0.883117  homme  ASY  0.72     0.320066  1.0  Normal  0.698020    Non
# 915  0.740260  homme  ASY  0.65     0.217247  0.0  Normal  0.569307    Oui
# 916  0.740260  femme   AA  0.65     0.391376  0.0     LVH  0.861386    Non
# 917  0.493506  homme  DNA  0.69     0.290216  0.0  Normal  0.856436    Non
#
#      DEPRESSION       PENTE  CŒUR
# 0            0.0  Ascendant     0
# 1            1.0       Plat     1
# 2            0.0  Ascendant     0
# 3            1.5       Plat     1
# 4            0.0  Ascendant     0
# ..           ...        ...   ...
# 913          1.2       Plat     1
# 914          3.4       Plat     1
# 915          1.2       Plat     1
# 916          0.0       Plat     1
# 917          0.0  Ascendant     0
#
# [918 rows x 12 columns]

# %%
#recoder les variables qualitatiives

#fonction permettant de recoder une serie
def serie_recoder(serie):
    return serie.astype('category').cat.codes

#fonction permettant de recoder toutes les variables qualitatiives du dataframe
def data_recoder_qual_var(datf):
    for col in qual_var:
        datf[col] = serie_recoder(datf[col])
    return datf

df = data_recoder_qual_var(df)
df
# Out:
#           AGE  SEXE  TDT   PAR  CHOLESTEROL  GAJ  ECG     FCMAX  ANGINE  \
# 0    0.519481     1    0  0.70     0.479270  0.0    1  0.851485       0
# 1    0.636364     0    3  0.80     0.298507  0.0    1  0.772277       0
# 2    0.480519     1    0  0.65     0.469320  0.0    2  0.485149       0
# 3    0.623377     0    1  0.69     0.354892  0.0    1  0.534653       1
# 4    0.701299     1    3  0.75     0.323383  0.0    1  0.603960       0
# ..        ...   ...  ...   ...          ...  ...  ...       ...     ...
# 913  0.584416     1    2  0.55     0.437811  0.0    1  0.653465       0
# 914  0.883117     1    1  0.72     0.320066  1.0    1  0.698020       0
# 915  0.740260     1    1  0.65     0.217247  0.0    1  0.569307       1
# 916  0.740260     0    0  0.65     0.391376  0.0    0  0.861386       0
# 917  0.493506     1    3  0.69     0.290216  0.0    1  0.856436       0
#
#      DEPRESSION   PENTE  CŒUR
# 0            0.0      0     0
# 1            1.0      2     1
# 2            0.0      0     0
# 3            1.5      2     1
# 4            0.0      0     0
# ..           ...    ...   ...
# 913          1.2      2     1
# 914          3.4      2     1
# 915          1.2      2     1
# 916          0.0      2     1
# 917          0.0      0     0
#
# [918 rows x 12 columns]

# %%
#creer un dataframe x qui va contenir de age a pente et y coeur
X = df.iloc[:,:-1]
y= df.CŒUR

# %%
#train_test_split() fonction on va lui donner en parametre x et y et le taux 0.3
X_train, y_test = model_selection.train_test_split(X, y, test_size=0.3, random_state = 0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-54a45a6197bf> in <module>
#       1 #train_test_split() fonction on va lui donner en parametre x et y et le taux 0.3
# ----> 2 X_train, y_test = model_selection.train_test_split(X, y, test_size=0.3, random_state = 0)
#
# ValueError: too many values to unpack (expected 2)

# %%
print ("X_train: ")
X_train
# Out:
# X_train:
#           AGE  SEXE  TDT    PAR  CHOLESTEROL  GAJ  ECG     FCMAX  ANGINE  \
# 76   0.415584     1    1  0.590     0.877280  0.0    1  0.643564       0
# 48   0.467532     1    3  0.560     0.563847  0.0    1  0.910891       0
# 304  0.662338     1    1  0.475     0.000000  1.0    1  0.623762       0
# 263  0.766234     1    1  0.650     0.208955  0.0    1  0.618812       0
# 744  0.779221     1    1  0.585     0.381426  1.0    1  0.792079       1
# ..        ...   ...  ...    ...          ...  ...  ...       ...     ...
# 835  0.701299     1    1  0.550     0.396352  0.0    1  0.623762       1
# 192  0.623377     1    0  0.650     0.406302  0.0    1  0.792079       0
# 629  0.740260     0    1  0.640     0.502488  0.0    0  0.787129       0
# 559  0.831169     1    1  0.670     0.452736  0.0    1  0.504950       1
# 684  0.610390     1    3  0.540     0.402985  0.0    1  0.752475       0
#
#      DEPRESSION   PENTE
# 76           0.0      2
# 48           1.0      2
# 304          2.2      2
# 263          0.0      2
# 744          1.4      0
# ..           ...    ...
# 835          2.8      2
# 192          0.0      0
# 629          0.0      0
# 559          4.0      1
# 684          0.0      0
#
# [642 rows x 11 columns]

# %%
print ("y_train: ")
y_train
# Out:
# y_train:
# 76     1
# 48     0
# 304    1
# 263    1
# 744    1
#       ..
# 835    1
# 192    0
# 629    0
# 559    1
# 684    1
# Name: CŒUR, Length: 642, dtype: int64

# %%
print("X_test: ")
X_test
# Out:
# X_test:
#           AGE  SEXE  TDT    PAR  CHOLESTEROL  GAJ  ECG     FCMAX  ANGINE  \
# 306  0.714286     1    1  0.575     0.000000  1.0    1  0.767327       0
# 711  0.857143     1    1  0.600     0.500829  0.0    0  0.747525       0
# 298  0.662338     1    1  0.550     0.000000  1.0    1  0.455446       0
# 466  0.714286     1    3  0.600     0.000000  0.0    2  0.618812       1
# 253  0.805195     1    0  0.700     0.449420  0.0    1  0.752475       0
# ..        ...   ...  ...    ...          ...  ...  ...       ...     ...
# 49   0.532468     1    1  0.550     0.479270  0.0    1  0.841584       0
# 456  0.792208     1    3  0.600     0.000000  0.0    1  0.396040       1
# 342  0.792208     1    1  0.550     0.000000  1.0    1  0.559406       0
# 907  0.571429     1    1  0.600     0.280265  0.0    1  0.712871       1
# 116  0.493506     1    1  0.600     0.467662  0.0    1  0.841584       0
#
#      DEPRESSION   PENTE
# 306          0.1      2
# 711          0.4      2
# 298          0.0      2
# 466          2.5      2
# 253          1.0      0
# ..           ...    ...
# 49           0.0      2
# 456          0.0      2
# 342          1.4      2
# 907          2.8      1
# 116          0.0      2
#
# [276 rows x 11 columns]

# %%
print()
y_test
# Out:
# 306    1
# 711    0
# 298    1
# 466    1
# 253    0
#       ..
# 49     1
# 456    1
# 342    1
# 907    1
# 116    1
# Name: CŒUR, Length: 276, dtype: int64

# %%
#instanciation du modele
regLog_mod = linear_model.LogisticRegression()

# %%
#entrainer le modele
regLog_mod.fit(X_train,)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-dda3b1d00ea7> in <module>
#       1 #entrainer le modele
# ----> 2 regLog_mod.fit(X_train,)
#
# NameError: name 'regLog_mod' is not defined

# %%
#score entrainement
regLog_mod.score(X_train, y_train)*100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-3231d20280f5> in <module>
#       1 #score entrainement
# ----> 2 regLog_mod.score(X_train, y_train)*100
#
# NameError: name 'regLog_mod' is not defined

# %%
#score test
regLog_mod.score(X_test, y_test)*100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-49c7d72033cb> in <module>
#       1 #score test
# ----> 2 regLog_mod.score(X_test, y_test)*100
#
# NameError: name 'regLog_mod' is not defined

# %%
#construire la matrice de confusion 
confusion_matrix(y_test,(X_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-fcbb263ff57b> in <module>
#       1 #construire la matrice de confusion
# ----> 2 confusion_matrix(y_test,(X_test))
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     294
#     295     """
# --> 296     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     297     if y_type not in ("binary", "multiclass"):
#     298         raise ValueError("%s is not supported" % y_type)
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      90
#      91     if len(y_type) > 1:
# ---> 92         raise ValueError("Classification metrics can't handle a mix of {0} "
#      93                          "and {1} targets".format(type_true, type_pred))
#      94
#
# ValueError: Classification metrics can't handle a mix of binary and continuous-multioutput targets

# %%
#la precision 
preci = precision_score(regLog_mod.predict())*100
preci
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-d13a94bbef8a> in <module>
#       1 #la precision
# ----> 2 preci = precision_score(regLog_mod.predict())*100
#       3 preci
#
# NameError: name 'regLog_mod' is not defined

# %%
#la sensibilite
(y_test, regLog_mod.predict(X_test))
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-54-88184b1f2674> in <module>
#       1 #la sensibilite
# ----> 2 (y_test, regLog_mod.predict(X_test))
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     307             Predicted class label per sample.
#     308         """
# --> 309         scores = self.decision_function(X)
#     310         if len(scores.shape) == 1:
#     311             indices = (scores > 0).astype(int)
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_base.py in decision_function(self, X)
#     280             class would be predicted.
#     281         """
# --> 282         check_is_fitted(self)
#     283
#     284         X = check_array(X, accept_sparse='csr')
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1039
#    1040     if not attrs:
# -> 1041         raise NotFittedError(msg % {'name': type(estimator).__name__})
#    1042
#    1043
#
# NotFittedError: This LogisticRegression instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.
